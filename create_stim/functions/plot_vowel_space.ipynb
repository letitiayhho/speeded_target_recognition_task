# %%
import plotly.express as px
import numpy as np
import pandas as pd
import os

# %%
# Plot vowel space by subject
fig = px.scatter(df,
                 x = "f2", 
                 y = "f1", 
                 color = "subject",
                range_x = [0, 3500],
                range_y = [0, 1400],
                height = 700)
fig.show()
fig.write_html("vowel_spaces_by_subject.html")
# Out:
# <div>                            <div id="630ca7cf-a2ba-455d-ab4f-b873815e77e5" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("630ca7cf-a2ba-455d-ab4f-b873815e77e5")) {                    Plotly.newPlot(                        "630ca7cf-a2ba-455d-ab4f-b873815e77e5",                        [{"hovertemplate":"subject=subj09<br>f2=%{x}<br>f1=%{y}<extra></extra>","legendgroup":"subj09","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"subj09","orientation":"v","showlegend":true,"type":"scatter","x":[1326.02752685547,2052.63249206543,1831.54847717285,2012.83490459736,1453.86461639404,2054.22662908381,1992.99221567007,2023.33967808315,1852.24545522837,1915.92647298177,1394.16782633464,1278.99639892578,1402.92221679688,1455.415178571
# ...

# %%
# Plot vowel space by vowel
fig = px.scatter(df,
                 x = "f2", 
                 y = "f1", 
                 color = "vowel",
                range_x = [0, 3500],
                range_y = [0, 1400],
                height = 700)
fig.show()
fig.write_html("vowel_spaces_by_vowel.html")
# Out:
# <div>                            <div id="1ec34d7c-1767-464c-8c1c-491f129ed799" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ec34d7c-1767-464c-8c1c-491f129ed799")) {                    Plotly.newPlot(                        "1ec34d7c-1767-464c-8c1c-491f129ed799",                        [{"hovertemplate":"vowel=AE<br>f2=%{x}<br>f1=%{y}<extra></extra>","legendgroup":"AE","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"AE","orientation":"v","showlegend":true,"type":"scatter","x":[1326.02752685547,2052.63249206543,1831.54847717285,2012.83490459736,1453.86461639404,2054.22662908381,1992.99221567007,2023.33967808315,1852.24545522837,1915.92647298177,1737.97214471726,1724.71528705798,1689.79472423735,1713.1481355366,1559.2286834
# ...
